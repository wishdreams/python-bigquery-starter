# %% [markdown]
# ### A quick look at "UNNEST" and BigQuery with Pandas

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
from constants import PROJECT_ID
import pandas as pd

# Use a service account for authentication onto GCP
credentials = service_account.Credentials.from_service_account_file('secrets/sa_key_01.json')

# The project id to which the service account has access
project_id = PROJECT_ID

# Establish a connection to the client
client = bigquery.Client(credentials= credentials, project=project_id)

# Perform a query
query = client.query(
"""
SELECT event_date, event_timestamp, event_params.value.string_value as page_location 
FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210131`,
UNNEST(event_params) AS event_params
WHERE event_params.key = 'page_location'
""")

#Convert output into a pandas dataframe
df = query.to_dataframe()
df
# Out:
#       event_date   event_timestamp  \
# 0       20210131  1612069510766593
# 1       20210131  1612069529243877
# 2       20210131  1612069515781635
# 3       20210131  1612069530073506
# 4       20210131  1612069510766593
# ...          ...               ...
# 26484   20210131  1612068327961419
# 26485   20210131  1612068335640396
# 26486   20210131  1612068908660405
# 26487   20210131  1612068361050112
# 26488   20210131  1612074949444471
#
#                                            page_location
# 0               https://shop.googlemerchandisestore.com/
# 1               https://shop.googlemerchandisestore.com/
# 2               https://shop.googlemerchandisestore.com/
# 3               https://shop.googlemerchandisestore.com/
# 4               https://shop.googlemerchandisestore.com/
# ...                                                  ...
# 26484           https://shop.googlemerchandisestore.com/
# 26485           https://shop.googlemerchandisestore.com/
# ...

# %% [markdown]
# #### Query info

# %%
query.
# Out:
# 0

# %% [markdown]
# #### What is a dataframe?

# %%
values = {'a':[1,2,3],
          'b':[2,4,6]}

pd.DataFrame(values)
# Out:
#    a  b
# 0  1  2
# 1  2  4
# 2  3  6

# %% [markdown]
# #### Quick EDA

# %%
# Info on data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26489 entries, 0 to 26488
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_date       26489 non-null  object
#  1   event_timestamp  26489 non-null  Int64
#  2   page_location    26489 non-null  object
# dtypes: Int64(1), object(2)
# memory usage: 646.8+ KB

# %%
# Look at numerical values in detail
df.describe()
# Out:
#        event_timestamp
# count     2.648900e+04
# mean      1.612095e+15
# std       2.525873e+10
# min       1.612051e+15
# 25%       1.612073e+15
# 50%       1.612095e+15
# 75%       1.612117e+15
# max       1.612138e+15

# %% [markdown]
# #### Examine page location

# %%
# Count of unique values
df.page_location.value_counts()

# %%
query2 = client.query("""
SELECT event_date, event_params.value.string_value as page_location, COUNT(page_location) as page_count 
FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210131`,
UNNEST(event_params) AS event_params
WHERE event_params.key = 'page_location'
GROUP BY event_date, page_location
HAVING page_count>100"""
)

df2 = query2.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-121-b0773b7b96ad> in <module>
#       8 )
#       9
# ---> 10 df2 = query2.to_dataframe()
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\job\query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype)
#    1797                 :mod:`shapely` library cannot be imported.
#    1798         """
# -> 1799         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1800         return query_result.to_dataframe(
#    1801             bqstorage_client=bqstorage_client,
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
# ...

# %%
# Describe page count stats

# %%
# Plot page count
df2.page_count.plot(kind='hist')

# %%
import seaborn as sns

sns.distplot(df2.page_count, bins=100)

# %%
ax = df.groupby(['consumer_gender','products_industry_name']).size().unstack().plot(kind='bar',stacked=True)
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
df.consumer_gender.value_counts().plot(kind='bar')
